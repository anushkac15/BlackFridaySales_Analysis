# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# ## Analyzing dataset

# %%
df = pd.read_csv("BlackFriday.csv")

# %%
df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 537572  1004737  P00193542      M  36-45          16             C
# 537573  1004737  P00111142      M  36-45          16             C
# 537574  1004737  P00345942      M  36-45          16             C
# 537575  1004737  P00285842      M  36-45          16             C
# 537576  1004737  P00118242      M  36-45          16             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 537577 entries, 0 to 537576
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     537577 non-null  int64
#  1   Product_ID                  537577 non-null  object
#  2   Gender                      537577 non-null  object
#  3   Age                         537577 non-null  object
#  4   Occupation                  537577 non-null  int64
#  5   City_Category               537577 non-null  object
#  6   Stay_In_Current_City_Years  537577 non-null  object
#  7   Marital_Status              537577 non-null  int64
#  8   Product_Category_1          537577 non-null  int64
#  9   Product_Category_2          370591 non-null  float64
#  10  Product_Category_3          164278 non-null  float64
#  11  Purchase                    537577 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# ...

# %% [markdown]
# ### Analyze null value

# %%
df.isnull()
# Out:
#         User_ID  Product_ID  Gender    Age  Occupation  City_Category  \
# 0         False       False   False  False       False          False
# 1         False       False   False  False       False          False
# 2         False       False   False  False       False          False
# 3         False       False   False  False       False          False
# 4         False       False   False  False       False          False
# ...         ...         ...     ...    ...         ...            ...
# 537572    False       False   False  False       False          False
# 537573    False       False   False  False       False          False
# 537574    False       False   False  False       False          False
# 537575    False       False   False  False       False          False
# 537576    False       False   False  False       False          False
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# ...

# %%
df.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            166986
# Product_Category_3            373299
# Purchase                           0
# dtype: int64

# %%
df.dropna()
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 1       1000001  P00248942      F   0-17          10             A
# 6       1000004  P00184942      M  46-50           7             B
# 13      1000005  P00145042      M  26-35          20             A
# 14      1000006  P00231342      F  51-55           9             A
# 16      1000006   P0096642      F  51-55           9             A
# ...         ...        ...    ...    ...         ...           ...
# 537549  1004734  P00345842      M  51-55           1             B
# 537551  1004735  P00313442      M  46-50           3             C
# 537562  1004736  P00146742      M  18-25          20             A
# 537571  1004737  P00221442      M  36-45          16             C
# 537573  1004737  P00111142      M  36-45          16             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 1                               2               0                   1
# ...

# %%
del df["Product_Category_2"]
del df["Product_Category_3"]

# %%
df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 537572  1004737  P00193542      M  36-45          16             C
# 537573  1004737  P00111142      M  36-45          16             C
# 537574  1004737  P00345942      M  36-45          16             C
# 537575  1004737  P00285842      M  36-45          16             C
# 537576  1004737  P00118242      M  36-45          16             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %% [markdown]
# ### Analyzing columns
# #### find the unique in each column

# %%
df['User_ID'].nunique()
# Out:
# 5891

# %%
df['Product_ID'].nunique()
# Out:
# 3623

# %%
df['Gender'].nunique()
# Out:
# 2

# %%
df['Gender'].unique()
# Out:
# array(['F', 'M'], dtype=object)

# %%
df['Age'].nunique()
# Out:
# 7

# %%
df['Age'].unique()
# Out:
# array(['0-17', '55+', '26-35', '46-50', '51-55', '36-45', '18-25'],
#       dtype=object)

# %%
df['Occupation'].unique()
# Out:
# array([10, 16, 15,  7, 20,  9,  1, 12, 17,  0,  3,  4, 11,  8, 19,  2, 18,
#         5, 14, 13,  6], dtype=int64)

# %%
df['City_Category'].unique()
# Out:
# array(['A', 'C', 'B'], dtype=object)

# %%
df['Stay_In_Current_City_Years'].unique()
# Out:
# array(['2', '4+', '3', '1', '0'], dtype=object)

# %%
df['Marital_Status'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df['Product_Category_1'].unique()
# Out:
# array([ 3,  1, 12,  8,  5,  4,  2,  6, 14, 11, 13, 15,  7, 16, 18, 10, 17,
#         9], dtype=int64)

# %%
df['Purchase'].sum()/len(df['Purchase'])
# Out:
# 9333.859852635065

# %%
for column in df.columns:
    print(column+" : "+str(df[column].nunique()))
# Out:
# User_ID : 5891
# Product_ID : 3623
# Gender : 2
# Age : 7
# Occupation : 21
# City_Category : 3
# Stay_In_Current_City_Years : 5
# Marital_Status : 2
# Product_Category_1 : 18
# Purchase : 17959

# %% [markdown]
# ### 1. Analysis on the basis of gender column

# %%
df['Gender']
# Out:
# 0         F
# 1         F
# 2         F
# 3         F
# 4         M
#          ..
# 537572    M
# 537573    M
# 537574    M
# 537575    M
# 537576    M
# Name: Gender, Length: 537577, dtype: object

# %%
df[df['Gender']=='M']
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 4       1000002  P00285442      M    55+          16             C
# 5       1000003  P00193542      M  26-35          15             A
# 6       1000004  P00184942      M  46-50           7             B
# 7       1000004  P00346142      M  46-50           7             B
# 8       1000004   P0097242      M  46-50           7             B
# ...         ...        ...    ...    ...         ...           ...
# 537572  1004737  P00193542      M  36-45          16             C
# 537573  1004737  P00111142      M  36-45          16             C
# 537574  1004737  P00345942      M  36-45          16             C
# 537575  1004737  P00285842      M  36-45          16             C
# 537576  1004737  P00118242      M  36-45          16             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 4                              4+               0                   8
# ...

# %% [markdown]
# ### #How many times males and females purchased something using Pie Chart and bar graph

# %%
data = pd.DataFrame({'Ratio' : [len(df[df['Gender']=='M']), len(df[df['Gender']=='F'])]}, index=['Male', 'Female'])

# %%
data
# Out:
#          Ratio
# Male    405380
# Female  132197

# %%
data.plot.pie(y='Ratio', autopct='%0.1f')
# Out:
# <Axes: ylabel='Ratio'>

# %% [markdown]
# #### #Second approach

# %%
df.groupby('Gender').size().plot(kind='pie',
                                 autopct='%0.1f',
                                 title = 'Gender Ratio')
# Out:
# <Axes: title={'center': 'Gender Ratio'}>

# %% [markdown]
# #### #Bar Graph

# %%
df.groupby('Gender').size().plot(kind = 'bar',
                                 title='Gender Ratio')
# Out:
# <Axes: title={'center': 'Gender Ratio'}, xlabel='Gender'>

# %% [markdown]
# #### #How much money male and female spend on product using pie chart

# %%
df.groupby('Gender')['Purchase'].sum().plot(kind='pie', autopct = '%0.1f')
# Out:
# <Axes: ylabel='Purchase'>

# %% [markdown]
# #### #Per product spend by male and female respectively

# %%
df.groupby('Gender')['Purchase'].mean().plot(kind='pie', autopct='%0.1f')
# Out:
# <Axes: ylabel='Purchase'>

# %% [markdown]
# ### 2. Analysis on the basis of Age Column

# %% [markdown]
# #### #How many Product they have purchsed in each age group by bar chart

# %%
df.groupby("Age").size().plot(kind='bar', title='Purchase Distribution By Age')
# Out:
# <Axes: title={'center': 'Purchase Distribution By Age'}, xlabel='Age'>

# %% [markdown]
# #### #Total number of Product per unique age range

# %%
for i in df['Age'].unique():
    print(i, ":", len(df[df['Age'] == i]))
# Out:
# 0-17 : 14707
# 55+ : 20903
# 26-35 : 214690
# 46-50 : 44526
# 51-55 : 37618
# 36-45 : 107499
# 18-25 : 97634

# %% [markdown]
# #### #Unique product

# %%
lst = []
for i in df['Age'].unique():
    lst.append([i, df[df['Age']==i]['Product_ID'].nunique()])
data = pd.DataFrame(lst, columns = ['Age', 'Products'])

# %%
data
# Out:
#      Age  Products
# 0   0-17      2300
# 1    55+      2573
# 2  26-35      3419
# 3  46-50      3099
# 4  51-55      2877
# 5  36-45      3318
# 6  18-25      3213

# %% [markdown]
# #### #Bar Graph

# %%
data.plot.bar(x='Age')
# Out:
# <Axes: xlabel='Age'>

# %% [markdown]
# #### #Total amount spend on products by each age group

# %%
df.groupby('Age')['Purchase'].sum().plot(kind='bar', title = 'Amount spend by Age')
# Out:
# <Axes: title={'center': 'Amount spend by Age'}, xlabel='Age'>

# %% [markdown]
# #### #Average they have spend on most on per product

# %%
df.groupby('Age')['Purchase'].mean()
# Out:
# Age
# 0-17     9020.126878
# 18-25    9235.197575
# 26-35    9314.588970
# 36-45    9401.478758
# 46-50    9284.872277
# 51-55    9620.616620
# 55+      9453.898579
# Name: Purchase, dtype: float64

# %%
df.groupby('Age')['Purchase'].mean().plot(kind='pie', autopct='%0.1f',title = 'Amount spend by Age')
# Out:
# <Axes: title={'center': 'Amount spend by Age'}, ylabel='Purchase'>

# %% [markdown]
# ### 3. Analyis based on Marital Status

# %%
df.groupby('Marital_Status').size().plot(kind='pie', autopct='%0.1f')
# Out:
# <Axes: >

# %% [markdown]
# ### 4. Analysis based on age and gender together

# %%
sns.set(rc={'figure.figsize' : (12,4)})
sns.countplot(x='Age', hue='Gender', data=df)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.set(rc={'figure.figsize': (12,4)})
sns.countplot(x='Gender', hue='Age', data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %% [markdown]
# ### 5. Analysis based on marital status and gender together

# %%
sns.countplot(x='Gender', hue='Marital_Status', data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %% [markdown]
# ### 6. Analysis on City_Category

# %%
sns.countplot(x=df['City_Category'])
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
df.groupby('City_Category').size().plot(kind='pie', autopct='%0.1f')
# Out:
# <Axes: >

# %% [markdown]
# ### 7. Analysis  based on Age and City_Category together

# %%
sns.countplot(x='City_Category', hue='Age',data=df)
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
sns.countplot(x='Age', hue='City_Category',data=df)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %% [markdown]
# ### 8. Analysis based on City_Category and Gender together

# %%
sns.countplot(x='Gender', hue='City_Category', data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %% [markdown]
# ### 9. Analysis based on Age and Marital Status

# %%
sns.countplot(x='Age', hue='Marital_Status',data=df)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.countplot(x='Marital_Status', hue='Age',data=df)
# Out:
# <Axes: xlabel='Marital_Status', ylabel='count'>

# %% [markdown]
# ### 10. Analysis based on City_Category and Amount spend

# %%
df.groupby('City_Category')['Purchase'].sum().plot(kind='pie', autopct='%0.1f', title='Amount spend in each city')
# Out:
# <Axes: title={'center': 'Amount spend in each city'}, ylabel='Purchase'>

# %%
df.groupby('City_Category')['Purchase'].mean().plot(kind='pie', autopct='%0.1f', title='Amount spend in each city')
# Out:
# <Axes: title={'center': 'Amount spend in each city'}, ylabel='Purchase'>

# %% [markdown]
# ### 11. Analysis based on Stay in Currrent City Years

# %%
sns.countplot(x='Stay_In_Current_City_Years', data =df)
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %% [markdown]
# ### 12. Analysis based on Stay in Current City Years and Gender

# %%
sns.countplot(x='Stay_In_Current_City_Years',hue = 'Gender', data =df)
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %% [markdown]
# ### 13. Analysis based on Stay in Current City Years and Marital Status

# %%
sns.countplot(x='Stay_In_Current_City_Years',hue = 'Marital_Status', data =df)
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %% [markdown]
# ### 14. Analysis based on Stay in Current City Years and City_Category

# %%
sns.countplot(x='Stay_In_Current_City_Years', hue = 'City_Category', data=df)
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %% [markdown]
# ### 15. Total amount spend by Stay in current city years column

# %%
df.groupby('Stay_In_Current_City_Years')['Purchase'].sum().plot(kind='pie', autopct='%0.1f')
# Out:
# <Axes: ylabel='Purchase'>

# %%
df.groupby('Stay_In_Current_City_Years')['Purchase'].mean().plot(kind='pie', autopct='%0.1f')
# Out:
# <Axes: ylabel='Purchase'>

# %% [markdown]
# ### 16. Analysis based on Occupation Column

# %%
sns.set(rc={'figure.figsize' : (5,4)})
sns.countplot(x='Occupation', data=df)
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
df.groupby('Occupation').size().sort_values().plot(kind='bar')
# Out:
# <Axes: xlabel='Occupation'>

# %% [markdown]
# #### #Total amount spend by Ocuuptaion

# %%
df.groupby('Occupation')['Purchase'].sum().sort_values().plot(kind='bar')
# Out:
# <Axes: xlabel='Occupation'>

# %%
df.groupby('Occupation')['Purchase'].mean().sort_values().plot(kind='bar')
# Out:
# <Axes: xlabel='Occupation'>

# %% [markdown]
# ### 17. Analysis based on Occupation and Marital Status together

# %%
sns.countplot(x='Occupation', hue='Marital_Status', data=df)
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %% [markdown]
# ### 18. Analysis based on Occupation and Gender

# %%
sns.set(rc={'figure.figsize' : (8,8)})
sns.countplot(x='Occupation', hue='Gender', data=df)
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %% [markdown]
# ### 19. How many unique Product Id people are buying from different Occupation

# %%
sns.set(rc={'figure.figsize' : (6,3)})
df.groupby('Occupation').nunique()['Product_ID'].plot(kind='bar')
# Out:
# <Axes: xlabel='Occupation'>

# %%
df.groupby('Occupation').nunique()['Product_ID'].sort_values().plot(kind='bar')
# Out:
# <Axes: xlabel='Occupation'>

# %% [markdown]
# ### 20. Analysis based on Product_Category Column

# %%
df.groupby('Product_Category_1').size().sort_values().plot(kind='bar')
# Out:
# <Axes: xlabel='Product_Category_1'>

# %% [markdown]
# #### #Amount spend by people on each Product Category 1

# %%
df.groupby('Product_Category_1')['Purchase'].sum().sort_values().plot(kind='bar')
# Out:
# <Axes: xlabel='Product_Category_1'>

# %%
df.groupby('Product_Category_1')['Purchase'].mean().sort_values().plot(kind='bar')
# Out:
# <Axes: xlabel='Product_Category_1'>

# %% [markdown]
# ### 21. Analysis on top 10 Product_Id

# %% [markdown]
# #### #10 Most Selling Products

# %%
df.groupby('Product_ID').size().nlargest(10).sort_values().plot(kind='bar')
# Out:
# <Axes: xlabel='Product_ID'>

# %% [markdown]
# #### #Amount spend by people on Top 10 Product Id
# #### #Top 10 Products where people spending most

# %%
df.groupby('Product_ID')['Purchase'].sum().nlargest(10)
# Out:
# Product_ID
# P00025442    27532426
# P00110742    26382569
# P00255842    24652442
# P00184942    24060871
# P00059442    23948299
# P00112142    23882624
# P00110942    23232538
# P00237542    23096487
# P00057642    22493690
# P00010742    21865042
# Name: Purchase, dtype: int64

# %%
df.groupby('Product_ID')['Purchase'].sum().nlargest(10).sort_values().plot(kind='bar')
# Out:
# <Axes: xlabel='Product_ID'>

# %% [markdown]
# #### #Sum of the most 10 expensive products

# %%
df.groupby('Product_ID')['Purchase'].mean().nlargest(10).sort_values().plot(kind='bar')
# Out:
# <Axes: xlabel='Product_ID'>

# %% [markdown]
# #### #Analysis on Product_Category_1 and Gender Column Together

# %%
sns.countplot(x='Product_Category_1', hue='Gender', data=df)
# Out:
# <Axes: xlabel='Product_Category_1', ylabel='count'>

# %% [markdown]
# #### #Analysis on Product_Category_1 and Marital Status Column Together

# %%
sns.countplot(x='Product_Category_1', hue='Marital_Status', data=df)
# Out:
# <Axes: xlabel='Product_Category_1', ylabel='count'>

# %% [markdown]
# ### 22. Analysis on new column which is join together gender and marital status

# %% [markdown]
# #### #Creating a new Column that combines marital Status and Gender

# %%
lst = []
for i in range(len(df)):
    lst.append(df['Gender'][i] + "_" + str(df['Marital_Status'][i]))
df['MaritalGender']=lst

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase  \
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200
# 2                          2               0                  12      1422
# 3                          2               0                  12      1057
# 4                         4+               0                   8      7969
#
#   MaritalGender
# 0           F_0
# 1           F_0
# 2           F_0
# 3           F_0
# 4           M_0

# %%
sns.countplot(x='MaritalGender', data = df)
# Out:
# <Axes: xlabel='MaritalGender', ylabel='count'>

# %% [markdown]
# #### #MaritalGender with Age

# %%
sns.countplot(x='MaritalGender', hue='Age', data=df)
# Out:
# <Axes: xlabel='MaritalGender', ylabel='count'>

# %% [markdown]
# #### #MaritalGender with Product_Category

# %%
sns.countplot(x='Product_Category_1', hue='MaritalGender', data=df)
# Out:
# <Axes: xlabel='Product_Category_1', ylabel='count'>

# %%
sns.countplot(x='MaritalGender', hue='Product_Category_1', data=df)
# Out:
# <Axes: xlabel='MaritalGender', ylabel='count'>

# %% [markdown]
# #### #MaritalGender with Stay in Current_City_Years

# %%
sns.countplot(x='Stay_In_Current_City_Years', hue='MaritalGender', data=df)
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %% [markdown]
# #### #MaritalGender with City_Category

# %%
sns.countplot(x='MaritalGender', hue='City_Category', data=df)
# Out:
# <Axes: xlabel='MaritalGender', ylabel='count'>
